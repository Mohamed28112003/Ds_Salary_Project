# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv('data_cleaned.csv')

# %%
df.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          742 non-null    object
#  1   Salary Estimate    742 non-null    object
#  2   Job Description    742 non-null    object
#  3   Rating             742 non-null    float64
#  4   Company Name       742 non-null    object
#  5   Location           742 non-null    object
#  6   Headquarters       742 non-null    object
#  7   Size               742 non-null    object
#  8   Founded            742 non-null    int64
#  9   Type of ownership  742 non-null    object
#  10  Industry           742 non-null    object
#  11  Sector             742 non-null    object
#  12  Revenue            742 non-null    object
#  13  Competitors        742 non-null    object
#  14  Salary_Per_Hour    742 non-null    int64
#  15  Employer Provdid   742 non-null    int64
# ...

# %%
df.describe()
# Out:
#            Rating      Founded  Salary_Per_Hour  Employer Provdid   \
# count  742.000000   742.000000       742.000000         742.000000
# mean     3.618868  1837.154987         0.032345           0.022911
# std      0.801210   497.183763         0.177034           0.149721
# min     -1.000000    -1.000000         0.000000           0.000000
# 25%      3.300000  1939.000000         0.000000           0.000000
# 50%      3.700000  1988.000000         0.000000           0.000000
# 75%      4.000000  2007.000000         0.000000           0.000000
# max      5.000000  2019.000000         1.000000           1.000000
#
#        Min_Salary  Max_Salary  Avg_Salary  Same_Location  Company_Age  \
# count  742.000000  742.000000  742.000000     742.000000   742.000000
# mean    74.068733  127.183288  100.626011       0.557951    49.389488
# std     31.869282   46.909006   38.855948       0.496965    53.962906
# min     10.000000   16.000000   13.500000       0.000000    -1.000000
# ...

# %%
df.dtypes
# Out:
# Job Title             object
# Salary Estimate       object
# Job Description       object
# Rating               float64
# Company Name          object
# Location              object
# Headquarters          object
# Size                  object
# Founded                int64
# Type of ownership     object
# Industry              object
# Sector                object
# Revenue               object
# Competitors           object
# Salary_Per_Hour        int64
# Employer Provdid       int64
# Min_Salary             int64
# Max_Salary             int64
# Avg_Salary           float64
# Company_name_txt      object
# Jop_Estate            object
# Same_Location          int64
# Company_Age            int64
# Python                 int64
# R_studio               int64
# Spark                  int64
# Aws                    int64
# Excel                  int64
# dtype: object

# %% [markdown]
# #Featrue Engineering

# %%
df['Job Title'].value_counts()
# Out:
# Data Scientist                     131
# Data Engineer                       53
# Senior Data Scientist               34
# Data Analyst                        15
# Senior Data Engineer                14
#                                   ...
# Data Scientist/ML Engineer           1
# Sr. Data Scientist                   1
# Data Engineer 4 - Contract           1
# Data Analyst - Asset Management      1
# Machine Learning Engineer (NLP)      1
# Name: Job Title, Length: 264, dtype: int64

# %%
# many jop titles
def jop_title(title):
  if 'data scientist' in title.lower():
    return 'data scientist'
  elif 'data engineer' in title.lower():
    return 'data engineer'
  elif 'analyst' in title.lower():
    return 'analyst'
  elif 'manger' in title.lower():
   return 'manger'
  elif 'director' in title.lower():
    return 'director'
  elif 'machine learning' in title.lower():
    return 'machine learning engineer'
  else:
    return 'na'

# %%
#seniority
def seniority(title):
    if 'sr' in title.lower() or 'senior' in title.lower() or 'sr' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
            return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower():
        return 'jr'
    else:
        return 'na'

# %%
df['Job Title_Simp']=df['Job Title'].apply(jop_title)
df['Job Title_Simp'].value_counts()
# Out:
# data scientist               279
# na                           206
# data engineer                119
# analyst                      102
# machine learning engineer     22
# director                      14
# Name: Job Title_Simp, dtype: int64

# %%
df['seniority'] = df['Job Title'].apply(seniority)
df.seniority.value_counts()
# Out:
# na        520
# senior    220
# jr          2
# Name: seniority, dtype: int64

# %%
df['Jop_Estate'].value_counts()
# Out:
#  CA             151
#  MA             103
#  NY              72
#  VA              41
#  IL              40
#  MD              35
#  PA              33
#  TX              28
#  WA              21
#  NC              21
#  NJ              17
#  FL              16
#  OH              14
#  TN              13
#  DC              11
#  CO              11
#  WI              10
#  IN              10
#  UT              10
#  AZ               9
#  MO               9
#  AL               8
#  GA               6
#  KY               6
#  DE               6
#  MI               6
#  CT               5
#  IA               5
#  LA               4
#  OR               4
#  NE               4
#  NM               3
#  KS               3
#  ID               2
#  MN               2
#  Los Angeles      1
#  RI               1
#  SC               1
# Name: Jop_Estate, dtype: int64

# %%
# Fix state Los Angeles
df['Jop_Estate']= df['Jop_Estate'].apply(lambda x: x.strip() if x.strip().lower() != 'los angeles' else 'CA')
df['Jop_Estate'].value_counts()
# Out:
# CA    152
# MA    103
# NY     72
# VA     41
# IL     40
# MD     35
# PA     33
# TX     28
# NC     21
# WA     21
# NJ     17
# FL     16
# OH     14
# TN     13
# DC     11
# CO     11
# WI     10
# UT     10
# IN     10
# AZ      9
# MO      9
# AL      8
# GA      6
# DE      6
# KY      6
# MI      6
# CT      5
# IA      5
# LA      4
# OR      4
# NE      4
# NM      3
# KS      3
# ID      2
# MN      2
# RI      1
# SC      1
# Name: Jop_Estate, dtype: int64

# %%
#  Job description length
df[' Job_description_len'] = df['Job Description'].apply(lambda x: len(x))
df[' Job_description_len'].head()
# Out:
# 0    2536
# 1    4783
# 2    3461
# 3    3883
# 4    2728
# Name:  Job_description_len, dtype: int64

# %%
df['Competitors'].value_counts()
# Out:
# -1                                                                                              460
# Novartis, Baxter, Pfizer                                                                         14
# Oak Ridge National Laboratory, National Renewable Energy Lab, Los Alamos National Laboratory     12
# Travelers, Allstate, State Farm                                                                  10
# Roche, GlaxoSmithKline, Novartis                                                                  9
#                                                                                                ...
# BrowserStack, Selenium Master, Perfecto Mobile                                                    1
# Boeing, Northrop Grumman, Raytheon                                                                1
# Unilever, Procter & Gamble, Henkel                                                                1
# ...

# %%
#competitros
df['num_comp'] = df['Competitors'].apply(lambda x: len(x.split(',')) if x != '-1' else 0)
df['num_comp'].value_counts()
# Out:
# 0    460
# 3    228
# 2     41
# 1     12
# 4      1
# Name: num_comp, dtype: int64

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Salary_Per_Hour', 'Employer Provdid ', 'Min_Salary', 'Max_Salary',
#        'Avg_Salary', 'Company_name_txt', 'Jop_Estate', 'Same_Location',
#        'Company_Age', 'Python', 'R_studio', 'Spark', 'Aws', 'Excel',
#        'Job Title_Simp', 'seniority', ' Job_description_len', 'num_comp'],
#       dtype='object')

# %%
df['Min_Salary']=df.apply(lambda x: x.Min_Salary*2 if x.Salary_Per_Hour ==1 else x.Min_Salary, axis =1)
df['Max_Salary']=df.apply(lambda x: x.Max_Salary*2 if x.Salary_Per_Hour ==1 else x.Max_Salary, axis =1)

# %%
df[df.Salary_Per_Hour ==1][['Salary_Per_Hour','Min_Salary','Max_Salary']]
# Out:
#      Salary_Per_Hour  Min_Salary  Max_Salary
# 165                1          34          48
# 177                1          42          68
# 197                1          36          50
# 202                1          42          68
# 210                1          30          50
# 246                1          34          48
# 271                1          42          68
# 337                1          36          50
# 345                1          48          78
# 357                1          42          68
# 363                1          50          56
# 408                1          42          58
# 409                1          20          34
# 492                1          36          50
# 509                1          48          78
# 533                1          42          68
# 542                1          50          56
# 617                1          42          58
# 618                1          20          34
# 645                1          54          94
# ...

# %% [markdown]
# #Data Visualization

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Salary_Per_Hour', 'Employer Provdid ', 'Min_Salary', 'Max_Salary',
#        'Avg_Salary', 'Company_name_txt', 'Jop_Estate', 'Same_Location',
#        'Company_Age', 'Python', 'R_studio', 'Spark', 'Aws', 'Excel',
#        'Job Title_Simp', 'seniority', ' Job_description_len', 'num_comp'],
#       dtype='object')

# %%
df['Rating'].hist()
# Out:
# <Axes: >

# %%
df['Avg_Salary'].hist()
# Out:
# <Axes: >

# %%
df['Job Title_Simp'].hist()
# Out:
# <Axes: >

# %%
df['Job Title_Simp'].hist()
# Out:
# <Axes: >

# %%
sns.heatmap(df[['Avg_Salary','Rating',]].corr(),annot=True)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Salary_Per_Hour', 'Employer Provdid ', 'Min_Salary', 'Max_Salary',
#        'Avg_Salary', 'Company_name_txt', 'Jop_Estate', 'Same_Location',
#        'Company_Age', 'Python', 'R_studio', 'Spark', 'Aws', 'Excel',
#        'Job Title_Simp', 'seniority', ' Job_description_len', 'num_comp'],
#       dtype='object')

# %%
df_cat = df[[  'Size','Type of ownership',  'Sector', 'Revenue',  'Jop_Estate','Same_Location', 'Python', 'R_studio',
       'Spark', 'Aws', 'Excel','Job Title_Simp', 'seniority']]

# %%
#Making Barplot for this category
for i in df_cat:
  cat_num=df_cat[i].value_counts()
  graph=sns.barplot(x=cat_num.index,y=cat_num)
  print("Graph For ",i)
  graph.set_xticklabels(graph.get_xticklabels(), rotation=90)
  plt.show()

# %%
#Location , Headquarters ,Company_name_txt,Industry only top 20
for i in df_cat[[ 'Headquarters' ,'Company_name_txt','Industry' ]]:
  cat_num=df_cat[i].value_counts()[:20]
  graph=sns.barplot(x=cat_num.index,y=cat_num)
  print("Graph For ",i)
  graph.set_xticklabels(graph.get_xticklabels(), rotation=90)
  plt.show()
# Out:
# Graph For  Headquarters
# Graph For  Company_name_txt
# Graph For  Industry

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Salary_Per_Hour', 'Employer Provdid ', 'Min_Salary', 'Max_Salary',
#        'Avg_Salary', 'Company_name_txt', 'Jop_Estate', 'Same_Location',
#        'Company_Age', 'Python', 'R_studio', 'Spark', 'Aws', 'Excel',
#        'Job Title_Simp', 'seniority', ' Job_description_len', 'num_comp'],
#       dtype='object')

# %%
#Looking For The  Avg Salary
graph=sns.barplot(x='Job Title_Simp',y='Avg_Salary',data=df)
graph.set_xticklabels(graph.get_xticklabels(), rotation=90)


plt.show()

# %%
graph=sns.scatterplot(x='Job Title_Simp',y='Avg_Salary',data=df)
graph.set_xticklabels(graph.get_xticklabels(), rotation=90)

plt.show()
# Out:
# <ipython-input-32-09809f2208b3>:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   graph.set_xticklabels(graph.get_xticklabels(), rotation=90)

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Salary_Per_Hour', 'Employer Provdid ', 'Min_Salary', 'Max_Salary',
#        'Avg_Salary', 'Company_name_txt', 'Jop_Estate', 'Same_Location',
#        'Company_Age', 'Python', 'R_studio', 'Spark', 'Aws', 'Excel',
#        'Job Title_Simp', 'seniority', ' Job_description_len', 'num_comp'],
#       dtype='object')

# %%
# Looking For  avg salary seniority Level In Each Jop
pd.pivot_table(df, index = ['Job Title_Simp','seniority'], values = 'Avg_Salary')
# Out:
#                                      Avg_Salary
# Job Title_Simp            seniority
# analyst                   jr          56.500000
#                           na          61.155405
#                           senior      79.092593
# data engineer             na          96.701220
#                           senior     124.689189
# data scientist            jr         106.500000
#                           na         107.043011
#                           senior     138.956522
# director                  na         168.607143
# machine learning engineer na         119.133333
#                           senior     142.071429
# na                        na          75.469799
#                           senior     109.061404

# %%
# see each jop state and title  avg salary
pd.pivot_table(df,index=['Jop_Estate','Job Title_Simp'],values=['Avg_Salary']).sort_values("Jop_Estate",ascending = False)
# Out:
#                            Avg_Salary
# Jop_Estate Job Title_Simp
# WI         na               54.000000
#            data scientist  113.500000
#            analyst          58.833333
# WA         na               97.500000
#            data scientist   99.764706
# ...                               ...
# AZ         analyst          55.000000
#            na              124.500000
# AL         na               43.750000
#            data engineer    65.000000
#            analyst          62.200000
#
# [109 rows x 1 columns]

# %%
#see each jop state avg salary
pd.pivot_table(df,index=['Jop_Estate'],values=['Avg_Salary']).sort_values("Avg_Salary",ascending = False)
# Out:
#             Avg_Salary
# Jop_Estate
# CA          123.513158
# IL          116.662500
# DC          110.181818
# MA          106.281553
# NJ          104.558824
# MI          100.250000
# RI          100.000000
# NY           98.652778
# NC           98.452381
# MD           97.357143
# KY           97.000000
# VA           95.621951
# UT           94.150000
# WA           93.190476
# PA           92.560606
# OR           92.125000
# IN           90.300000
# TX           89.392857
# OH           87.571429
# TN           87.115385
# KS           87.000000
# AZ           85.666667
# MN           85.500000
# MO           84.722222
# GA           80.666667
# IA           78.900000
# FL           77.625000
# CO           77.045455
# NM           74.333333
# WI           73.300000
# CT           71.100000
# SC           60.500000
# AL           57.937500
# ID           56.250000
# LA           52.250000
# NE           41.000000
# DE           27.500000

# %%
# see data scientist	 salary in each state
pd.pivot_table(df[df['Job Title_Simp'] == 'data scientist'], index = 'Jop_Estate', values = 'Avg_Salary').sort_values('Avg_Salary', ascending = False)
# Out:
#             Avg_Salary
# Jop_Estate
# DC          149.000000
# CA          142.522059
# UT          140.500000
# MO          127.666667
# IL          117.233333
# NC          117.000000
# NY          115.250000
# MA          113.750000
# WI          113.500000
# PA          113.333333
# MD          109.115385
# CO          108.666667
# VA          108.416667
# NJ          106.875000
# MI          106.625000
# OH          105.285714
# TX          100.730769
# WA           99.764706
# OR           98.500000
# FL           97.357143
# TN           96.000000
# IN           84.500000
# KY           84.000000
# CT           84.000000
# GA           81.333333
# NM           74.333333
# AZ           69.500000

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Salary_Per_Hour', 'Employer Provdid ', 'Min_Salary', 'Max_Salary',
#        'Avg_Salary', 'Company_name_txt', 'Jop_Estate', 'Same_Location',
#        'Company_Age', 'Python', 'R_studio', 'Spark', 'Aws', 'Excel',
#        'Job Title_Simp', 'seniority', ' Job_description_len', 'num_comp'],
#       dtype='object')

# %%
# avg salary for each Job_description
jop_desc=df[['Python','R_studio','Spark','Aws','Excel','Avg_Salary']]
for i in jop_desc.columns:
  print(i)
  print(pd.pivot_table(jop_desc,index=i,values='Avg_Salary').sort_values('Avg_Salary',ascending=False))
# Out:
# Python
#         Avg_Salary
# Python
# 1       112.653061
# 0        87.155714
# R_studio
#           Avg_Salary
# R_studio
# 0         100.706757
# 1          70.750000
# Spark
#        Avg_Salary
# Spark
# 1      113.347305
# 0       96.931304
# Aws
#      Avg_Salary
# Aws
# 1    112.559659
# 0     96.915194
# Excel
#        Avg_Salary
# Excel
# 0      102.953390
# 1       98.502577
# Avg_Salary
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-9cc9a1718f6c> in <cell line: 2>()
#       2 for i in jop_desc.columns:
#       3   print(i)
# ----> 4   print(pd.pivot_table(jop_desc,index=i,values='Avg_Salary').sort_values('Avg_Salary',ascending=False))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
# ...

# %%
df.to_csv('data.csv',index = False)
